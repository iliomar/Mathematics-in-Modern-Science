# %% [markdown]
# #MATE 4072, Proyecto 6
# Nombre: Iliomar Rodriguez Ramos
#
# \# de estudiante: 802-18-5066

# %% [markdown]
# Para estos ejercicios es necesaria la lectura de las seciones 4.3, 4.4 y 4.11 de este [texto](http://www.physics.miami.edu/~nearing/mathmethods/ode.pdf). También debe leer esta [sección](https://en.wikipedia.org/wiki/Sturm%E2%80%93Liouville_theory) en Wikipedia para el problema de Sturm-Liouville, que ya se ha mencionado antes.

# %% [markdown]
# #Ejercicio 1: 4.14 de la lectura
#
# Check the algebra in the derivation of the n = 0 Bessel equation. Explicitly verify that the general expression for a2k in terms of a0 is correct, Eq. (4.22).
#
# \
#
# $a_{l} = -a_{l-2}\frac{1}{(l+s)^{2}-n^{2}} = -a_{l-2}\frac{1}{l^{2}}$
#
# \
#
# en $l=2, 4, 6, ...$
#
# \
#
# Ahora, para $2k = l-2$, $k=1, 2, 3$
#
# \
#
# Por lo que se tiene
#
# $a_{2(k+1)} = -a_{2k}\frac{1}{(2(k+1))^{2}}$
#
# \
#
# Suponiendo que
#
# $C(k) = a_{2k} = (-1)^{k}a_{0}\frac{1}{2k(k!)^{2}}$
#
#
# Se puede omprobando que se cumple con $k=1$, $C(1) = a_{2} = a_{0}\frac{1}{4}$.
#
# \
#
# Ahora, para verificar que la expresión general para $a_{2k}$ en términos de $a_0$ es correctase se hace lo siguiente.
#
# \
#
# \
#
# $a_{2(k+1)} = -a_{2k}\frac{1}{(2(k+1))^{2}} = (-1)^{k}a_{0}\frac{1}{2^{2k}(k!)^{2}}\frac{1}{(2(k+1))^{2}}$
#
# \
#
# $\hspace{3em} = (-1)^{k+1}a_{0}\frac{1}{2^{2k}(k!)^{2}}\frac{1}{4(k+1)^{2}}$
#
# \
#
# $a_{2(k+1)} = (-1)^{k+1}a_{0}\frac{1}{2^{k+1}((k+1)!)^{2}} = C(k+1)$
#
# \
#
# Ya que se cumple para el caso de $k+1$ tambien se puede suponer que es cierto para todo numero entero en k, $k=1, 2, 3, \cdots$

# %% [markdown]
# #Ejercicio 2: 4.15 de la lectura
#
# Work out the Frobenius series solution to the Bessel equation for the $n = \frac{1}{2}$, $s = −\frac{1}{2}$ case. Graph both solutions, this one and Eq. (4.23).
#
# \
#
# \
#
# $a_{l} = -a_{l-2}\frac{1}{l(l+2s)} = -a_{l-2}\frac{1}{l(l-1)} \hspace{2em} l=2,4, 6,....$
#
# \
#
# $a_{2} = -a_{0}\frac{1}{2(1)} = -a_{0}\frac{1}{2!}$
#
# \
#
# $a_{4} = -a_{2}\frac{1}{4(3)} = a_{0}\frac{1}{2}\frac{1}{4\cdot 3} = a_{0}\frac{1}{4!}$
#
# \
#
# $a_{6} = -a_{4}\frac{2}{6(5)} = -a_{0}\frac{1}{2(4\cdot 3)}\frac{1}{(6)(5)} = -a_{0}\frac{1}{6!}$
#
# \
#
# $a_{2k} = (2k)^{k}x^{2k+\frac{1}{2}} = a_{0}\sum_{k=0}^{\infty}(-1)^{k}\frac{x^{2k}x^{-\frac{1}{2}}}{(2k)!}$
#
# \
#
# $y(x) = a_{0}x^{-\frac{1}{2}}\left[\frac{1}{0!} - \frac{x^{2}}{2!} + \frac{x^{4}}{4!} - \frac{x^{6}}{6!} + \cdots\right]$
#
# \
#
# \
#
# $\boxed{y(x) = a_{0}x^{-\frac{1}{2}}cos(x)}$

# %%
import pylab as plt
import math as ma
import numpy as np

x = np.linspace(1,50,100)
y_1 = np.zeros((len(x)))
y_2 = np.zeros((len(x)))


for k in range(50):
  y_1 += (-1)**k*(1/ma.factorial(2*i))*x**(2*i-1/2) 
for i in range(50):
  y_2 += (-1)**k*(1/ma.factorial(2*k+1))*x**(2*i+1/2)



plt.plot(x,y1,label="a_0x^-1/2*sin(x)")
plt.plot(x,y2,label="a_0x^-1/2*cos(x)")
plt.title("Funcion de Bessel")
plt.legend()
plt.show()

# %% [markdown]
# #Ejercicio 3: 4.16 de la lectura
#
# Derive the Frobenius series solution to the Bessel equation for the value of $n = 1$. Show that this method doesn’t yield a second solution for this case either
#
#
# \
#
# Sabemos que la ecuacion de Bessel esta dada por
#
# \
#
# $x^{2}y^{\prime\prime} + xy^{\prime}+(x^{2}+n^{2})y = 0$
#
# \
#
# Dado $n=1$ entonces
#
# \
#
# $x^{2}y^{\prime\prime} + xy^{\prime}+(x^{2}+1)y = 0$
#
# \
#
# La ecuacion anterior tiene puntos singularres en $x=0$. Por lo que una solucion para esta ecuacion es
#
# \
#
# $y(x) = \sum_{k=0}^{\infty}a_{k}x^{k+s} \hspace{2em} a_{0}\neq 0$
#
# \
#
# Ahora, hallando la primera y segunda derivada de esta solucion se tiene
#
# \
#
# $y^{\prime} = \sum_{k=0}^{\infty}(k+s)x^{k+s-1}$
#
# $y^{\prime\prime} = \sum_{k=0}^{\infty}(k+s)(k+s-1)x^{k+s-2}$
#
# \
#
# Sustituyendo estas derivadas en la ecuacion dada en $n=1$ se obtiene
#
# \
#
# $\sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s} + \sum_{k=0}^{\infty}a_{k}(k+s)x^{k+s}+\sum_{k=0}^{\infty}a_{k}x^{k+s+2} - \sum_{k=0}^{\infty} = 0$
#
# \
#
# $\sum_{k=0}^{\infty}a_{k}[(k+s)^{2}-1]x^{k+s}+\sum_{k=0}^{\infty}a_{k}x^{k+s+2} = 0$
#
# \
#
# En la primera sumatoria $k=l$ y en la segunda $k=l-2$
#
# \
#
# $\sum_{l=0}^{\infty}a_{l}[(l+s)^{2}-1]x^{l+s}+\sum_{l=2}^{\infty}a_{l-2}x^{l+s} = 0$
#
# \
#
# La potencia mas baja de x en esta ecuacion viene del termino $l=0$, en la primera suma.
#
# \
#
# $a_{0}[(0+s)^{2}-1] = 0 \hspace{2em} a_{0}\neq 0$
#
# \
#
# $s = +1 \hspace{2em} s = -1$
#
# \
#
# Para obtener la relacion de secuencia, evaluamos en cero el coeficiente de $x^{k+s} y se obtiene
#
# \
#
# $a_{l} [(l+s)^{2}-1]+a_{l-2} = 0$
#
# \
#
# $a_{l} = -a_{l-2}\frac{1}{(l+s+1)(l+s-1)} \hspace{2em} l=2, 4, 6$
#
# \
#
# \
#
# Para obtener $a_{1}$ evaluamos el coeficiente de $x^{s+1}$ a cero.
#
# \
#
# $a_{1}[(1+s)^{2}-1]=0 \xrightarrow{} a_{1}(s(s+1)) = 0$
#
# \
#
# Ahora, sabemos que $a_{1} = a_{3} = a_{5} = 0$
#
# \
#
# Por lo tanto, $a_{1} = 0$ para $s = +1$ y $s=-1$
#
# \
#
# Tenemos que con $s=1$
#
# \
#
# $a_{2} = -a_{0}\frac{1}{8}$
#
# \
#
# $a_{4} = a_{0}\frac{1}{192}$
#
# \
#
# $a_{6} = -a_{0}\frac{1}{9216}$
#
# \
#
# Esto se puede representar como
#
# \
#
# $a_{2k} = (-1)^{k}\frac{1}{2^{2k}(k+1)!k!}$
#
# \
#
# Por lo tanto,
#
# \
#
# $\boxed{y(x) = \sum_{k=0}^{\infty}(-1)^{k}\frac{\left(\frac{x}{2}\right)^{2k}x}{(k+1)!k!}}$
#
# \
#
# Ahora verificamos si se puede obtener los coeficientes para $s= -1$. Se sustituye en la ecuacion indicial
#
# \
#
# $a_{2k} = -a_{2(k-1)}\frac{1}{(2k-1)^{2}-1} = -a_{2(k-1)}\frac{1}{4k(k-1)}$
#
# \
#
# Se puede ver que para $k=1$, en $a_{2}$ se muestra un valor que no puede ser determinado.

# %% [markdown]
# #Ejercicio 4: 4.17 de la lectura
#
# Try using a Frobenius series method on $y+\frac{y^{\prime \prime}}{x^{3}} = 0$ around $x = 0$.
#
# \
#
# \
#
# Ya que esto esta de la forma
#
# \
#
# $y^{\prime\prime} + P(x)y^{\prime} + Q(x)y = 0$
#
# \
#
# \
#
#
# $y(x) = \sum_{k=0}^{\infty}a_{k}x^{k+s} \hspace{1em}$ es una solucion de una series de potencias de la ecuacion dada.
#
# \
#
# $y^{\prime} = \sum_{k=0}^{\infty}a_{k}(k+s)x^{k+s-1}$
#
# \
#
# $y^{\prime\prime} = \sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s-2}$
#
# \
#
# Sustituyendolo en la ecuacion dada se obtiene
#
# \
#
# $\sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s-2}+\frac{1}{x^{3}}\sum_{k=0}^{\infty}a_{k}x^{k+s} = 0$
#
# \
#
# $\sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s-2}+\sum_{k=0}^{\infty}a_{k}x^{k+s-3} = 0$
#
# \
#
# $\frac{1}{x^{2}}\left[\sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s}+\sum_{k=0}^{\infty}a_{k}x^{k+s-1}\right] = 0$
#
# \
#
# $\frac{1}{x^{2}}\left[\sum_{k=0}^{\infty}a_{k}(k+s)(k+s-1)x^{k+s}+\sum_{k=1}^{\infty}a_{k-1}x^{k+s}\right] = 0$
#
# \
#
# $a_{0}\left[s(s-1)\right] = 0$
#
# \
#
# $s=0$
#
# $a_{k}(k(k+1)) = -a_{k-1} \xrightarrow{} a_{k} = -\frac{a_{k-1}}{k(k+1)}$
#
# \
#
# \
#
# Luego de resolver esta recurrencia se puede obtener la solucion en la forma de series de Potencia
#
# \
#
# \
#
# $a_{1} = -a_{0}\frac{1}{2}$
#
# \
#
# $a_{2} = -a_{1}\frac{1}{6} = a_{0}\frac{1}{12}$
#
# \
#
# $a_{3} = -a_{2}\frac{1}{12} = -a_{0}\frac{1}{144}$
#
# \
#
# Esto se puede representar utilizando la siguiente serie de potencias
#
# \
#
# \
#
# $a_{k} = (-1)^{k}a_{0}\frac{1}{(k+1)!k!}$
#
# \
#
# \
#
# Finalmente usando la forma de la serie de Frobenius se tiene
#
# \
#
# \
#
#
# $\boxed{y(x) = \sum_{k=0}^{\infty} (-1)^{k}\frac{x^{k+1}}{(k+1)!k!}}$

# %% [markdown]
# #Ejercicio 5: 4.18 de la lectura
#
# Solve by Frobenius series $x^{2}u^{\prime \prime}+ 4xu^{\prime}+ (x^{2} + 2)u = 0$. You should be able to recognize the resulting series (after a little manipulation).
#
# \
#
# $u(x) = \sum_{k=0}^{\infty}a_{k}x^{k+s}\hspace{2em}(a_{0}\neq 0)$
#
# \
#
# $u^{\prime} = \sum_{k=0}^{\infty}a_{k}(k+s)x^{k+a-1}$
#
# \
#
# $u^{\prime\prime} = \sum_{k=0}^{\infty}a_{k}(k+s)(k+a-1)x^{k+a-2}$
#
# \
#
# Sustituyendo esto se obtiene
#
# \
#
# \
#
# $x^{2}\sum_{k=0}^{\infty}a_{k}(k+s)(k+a-1)x^{k+a-2} + 4x\sum_{k=0}^{\infty}a_{k}(k+s)x^{k+a-1} + (x^{2}+2)\sum_{k=0}^{\infty}a_{k}x^{k+s} = 0$
#
# \
#
# \
#
# $\sum_{k=0}^{\infty}\left[a_{k}(k+s)(k+a-1)x^{k+a} + 4a_{k}(k+s)x^{k+a} + a_{k}(x^{k+s+2}+2x^{k+s})\right] = 0$
#
# \
#
# $\sum_{k=0}^{\infty}a_{k}\left[((k+s)+1)((k+s)+2\right]x^{k+s} + \sum_{k^{\prime}=2}^{\infty}a_{k-2}x^{k^{\prime}+s} = 0$
#
# \
#
# $a_{0}[(s+1)(s+2)] = 0$
#
# \
#
# $s=-1, 2$
#
# \
#
# \
#
# Para $s=-1$
#
# \
#
# $a_{k}[((k+s)+1)((k+s)+2)] +a_{k-2}= 0$
#
# \
#
# \
#
# Tomando $k = 2l \hspace{2em} para\hspace{1em} k=1, 2, 3$
#
# \
#
#
# $a_{2l}[((2l+s)+1)((2l+s)+2)] +a_{2(l-1)}= 0$
#
# \
#
# \
#
# $a_{2l} = -\frac{a_{2(l-1)}}{((2l+s)+1)((2l+s)+2)}$
#
# \
#
# Por lo tanto,
#
# $a_{2} = -a_{0}\frac{1}{6}$
#
# \
#
# $a_{4} = -a_{2}\frac{1}{20} = a_{0}\frac{1}{5!}$
#
# \
#
# $a_{6} = -a_{4}\frac{1}{42} = -a_{0}\frac{1}{7!}$
#
# \
#
# Por lo tanto, se tiene
#
# $a_{2l} = (-1)^{l}a_{0}\frac{1}{(2l+1)!}$
#
# \
#
# Ahora la solucion para $s=-1$ es
#
# \
#
# $u_{1}(x) = A\sum_{l=0}^{\infty}(-1)^{l}\frac{1}{(2l+1)}x^{2l-1} = Ax^{-2}sin(x)$
#
# \
#
# Entonces, para $s=-2$ se tiene que
#
# \
#
# $a_{2l} = -a_{2(l-1)}\frac{1}{((2l-1)2l)} \hspace{1em}$
#
# Nuevamente, para $ l=1, 2, 3$ se tiene
#
# \
#
# Por lo tanto,
#
# $a_{2} = -a_{0}\frac{1}{6}$
#
# \
#
# $a_{4} = -a_{2}\frac{1}{20} = a_{0}\frac{1}{5!}$
#
# \
#
# $a_{6} = -a_{4}\frac{1}{42} = -a_{0}\frac{1}{7!}$
#
# \
#
# La solucion para $s=-2$ sera
#
# \
#
# $u_{2}(x) = B\sum_{l=0}^{\infty}(-1)^{l}\frac{1}{(2L)!}x^{2l-2} = Bx^{-2}cos(x)$
#
# \
#
# \
#
# Finalmente, se tiene que la solucion general es
#
# \
#
# $\boxed{u(x) = \frac{Asin(x)}{x^{2}}+\frac{Bcos(x)}{x^{2}}}$
#
#
#
# \
#
# \
#
# \

# %% [markdown]
# #Ejercicio 6: 4.47 de la lectura
#
# Solve for the complete solution of Eq. (4.55) for the case $C = 0$. For this, don’t use series methods, but get the closed form solution.
#
# \
#
# $(1-x^{2})y^{\prime\prime} - 2xy^{\prime}+Cy = 0$
#
# \
#
# En $C = 0$
#
# \
#
# $(1-x^{2})y^{\prime\prime} - 2xy^{\prime} = 0$
#
# \
#
# $y^{\prime\prime} + \frac{2x}{1-x^{2}}y^{\prime} = 0 \xrightarrow{} y^{\prime \prime} + \frac{2x}{x^{2}-1}y^{\prime} = 0$
#
# \
#
# \
#
# $y^{\prime} = u \hspace{2em} y^{\prime\prime} = u^{\prime}$
#
# \
#
# \
#
# Poniendolo en la ecuacion de arriva
#
# \
#
# \
#
# $u^{\prime} + \frac{2x}{x^{2}-1}u = 0$
#
# \
#
# $I_{F} = e^{\int \frac{2x}{x^{2}-1}} = e^{ln(x^{2}-1)} = x^{2}-1$
#
# \
#
# \
#
# La solucion es $u(x^{2} - 1) = \int 0(x^{2}-1)dx \xrightarrow{} u(x^{2}-1) = A \xrightarrow{} u = \frac{A}{x^{2}+1} \xrightarrow{} y^{\prime \prime} = \frac{A}{x^{2}+1}$
#
# \
#
# $\frac{dy}{dx} = \frac{A}{x^{2}-1}$
#
# \
#
# Ahora, $\frac{1}{x^{2}-1} =\frac{C}{x+1} + \frac{D}{x-1}$
#
# \
#
# Cuando $x = 1 \hspace{2em} D=\frac{1}{2}$
#
# \
#
# Cuando $x = -1 \hspace{2em} C = -\frac{1}{2}$
#
# \
#
# $\frac{dy}{dx} = \frac{A}{x}\left[-\frac{1}{x+1} + \frac{1}{x-1}\right] \xrightarrow{} \int dx = \frac{A}{2}\int \left[\frac{1}{x-1} - \frac{1}{x+1}\right]$
#
# \
#
# $y = \frac{A}{2}\left[ln(x-1)-ln(x+1)\right]+B$
#
# \
#
# $ = \frac{A}{2}ln\left(\frac{x-1}{x+1}\right) + B$
#
# \
#
# $ = Aln\left(\frac{x+1}{x-1}\right) + B \hspace{2em}$ donde $A = -\frac{A}{2}$
#
# \
#
# \
#
# Finalmente se obtiene
# $\boxed{y(x) = A\cdot tanh^{-1}(x)+B}$

# %% [markdown]
# #Ejercicio 7: 4.49 de la lectura
#
# Start with the equation $y\prime \prime+P(x)y\prime+Q(x)y = 0$ and assume that you have found one solution: $y = f(x)$. Perhaps you used series methods to find it.
#
# (a) Make the substitution $y(x) = f(x)g(x)$ and deduce a differential equation for $g$. Let $G = g \prime$ and solve the resulting first order equation for $G$. Finally write $g$ as an integral. This is one method (not necessarily the best) to find the second solution to a differential equation.
#
# \
#
# \
#
# \
#
# Si $y = f(x)$ es una de las soluciones entonces
#
# $f^{\prime \prime} + P(x)f^{\prime \prime}(x) + Q(x)f(x) = 0$
#
# \
#
# \
#
# $y(x) = f(x)g(x)$
#
# \
#
# $y^{\prime} = f(x)g^{\prime}+f^{\prime}g(x)$
#
# \
#
# $y^{\prime \prime} = f(x)g^{\prime\prime}(x)+2f^{\prime}(x)g^{\prime}(x)+g(x)f^{\prime\prime}(x)$
#
# \
#
# \
#
# Ahora $y^{\prime\prime}_P(x)y^{\prime}+Qy = 0$ implica
#
# \
#
# $(fg^{\prime\prime}+f^{\prime\prime}g+2f^{\prime}g^{\prime})+P(x)(fg^{\prime}+f^{\prime}g)+Q(x)fg =0$
#
# \
#
# $(f^{\prime\prime} + P(x)f^{\prime}+Q(x)f)g + (fg^{\prime \prime}+2f^{\prime}g^{\prime}+P(x)fg^{\prime}) = 0$
#
# \
#
# \
#
# Por lo tanto, tenemos
#
# \
#
# $fg^{\prime\prime} + 2f^{\prime}g^{\prime}+P(x)fg^{\prime} = 0$
#
# \
#
# $\therefore \frac{g^{\prime\prime}}{g^{\prime}} = -\left(\frac{2f^{\prime} + P(x)f}{f}\right)$
#
# \
#
# Sustituyendo $g^{\prime} = G$ y $g^{\prime\prime} = G^{\prime}$
#
# \
#
# $\frac{G^{\prime}}{G} = -\frac{2f^{\prime}+P(x)f}{f}$
#
# \
#
# Integrando ambos lados se tiene
#
# \
#
# \
#
# $ln|G| + -2ln|f| = -\int P(x)dx$
#
# \
#
# $ln|G|+2ln|f| = -\int P(x)dx$
#
# \
#
# $ln|G\cdot f^{2}| = -\int P(x)dx$
#
# \
#
# $Gf^{2} = e^{-\int P(x)dx}$
#
# \
#
# $g^{\prime}(x) = G = \frac{1}{f^{2}(x)}e^{-\int P(x)dx}$
#
# \
#
# $\boxed{g(x) = \int f^{-2}(x)e^{\int P(x)dx}dx}$
#
# \
#
#
#
#
#
#
# (b) Apply this result to the $\textit l= 0$ solution of Legendre’s equation to find another way to solve problem 4.47. Ans: y = f dx 1 f2 exp−P dx
#
# \
#
# $y(x) = tanh^{-1}(x)$
#
# \
#
# $(1-x^{2})y^{\prime\prime} - 2xy^{\prime}+Cy = 0$
#
# \
#
# Para $C=0$ tenemos $P(x) = -\frac{2x}{1-x^{2}}$, $Q = 0$
#
# \
#
# $\therefore g(x) = \int f^{-2}(x)\left(e^{\int \frac{2x}{1-x^{2}}dx}\right)dx = \int f^{-2}e^{-ln(1-x^{2})}dx  = \int f^{-2}(x)\frac{1}{1-x^{2}}dx$
#
# \
#
# $y(x) = f(x)g(x) = tanh^{-1}(x)\int \left(tanh^{-1}(x)\right)^{-2}\frac{1}{1-x^{2}}dx = -1$
#
# \
#
# $\boxed{y(x) = A\cdot tanh^{-1}(x)+B}
# $
